# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Times New Roman'

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-15/noise_j0_0/'

files = [
    '2019-02-15_10-10-04_measurements.log',
    '2019-02-15_10-10-04_desired_values.log',
    '2019-02-15_10-10-05_control_output.log',
    '2019-02-15_10-10-05_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data0_0 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-15/noise_j1_6/'

files = [
    '2019-02-15_10-11-17_measurements.log',
    '2019-02-15_10-11-18_desired_values.log',
    '2019-02-15_10-11-19_control_output.log',
    '2019-02-15_10-11-19_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data1_6 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-15/noise_j1_5/'

files = [
    '2019-02-15_10-10-38_measurements.log',
    '2019-02-15_10-10-39_desired_values.log',
    '2019-02-15_10-10-40_control_output.log',
    '2019-02-15_10-10-39_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data1_5 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-15/noise_j5_5/'

files = [
    '2019-02-15_10-12-01_measurements.log',
    '2019-02-15_10-12-02_desired_values.log',
    '2019-02-15_10-12-03_control_output.log',
    '2019-02-15_10-12-02_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data5_5 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-15/noise_j1_4/'

files = [
    '2019-02-15_10-19-33_measurements.log',
    '2019-02-15_10-19-33_desired_values.log',
    '2019-02-15_10-19-35_control_output.log',
    '2019-02-15_10-19-34_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data1_4 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-15/noise_j1_3/'

files = [
    '2019-02-15_10-22-09_measurements.log',
    '2019-02-15_10-22-09_desired_values.log',
    '2019-02-15_10-22-11_control_output.log',
    '2019-02-15_10-22-10_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data1_3 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
col = 'f'

data0_0[col].plot(label='sigma = 0')
data1_6[col].plot(label='sigma = 1e-6')
data1_5[col].plot(label='sigma = 1e-5')
data5_5[col].plot(label='sigma = 5e-5')
data1_4[col].plot(label='sigma = 1e-4')
data1_3[col].plot(label='sigma = 1e-3')

data0_0['f_d'].plot(label='f_d')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_noise_j.ipynb -- f')

plt.legend()

# %%
col = 'e'

data1_4[col].plot(label='sigma = 1e-4')
data5_5[col].plot(label='sigma = 5e-5')
data1_5[col].plot(label='sigma = 1e-5')
data1_6[col].plot(label='sigma = 1e-6')
data0_0[col].plot(label='sigma = 0')

data0_0['f_d'].plot(label='f_d')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_noise_j.ipynb -- f')

plt.legend()

# %% [raw]
# fig= plt.figure()
# a1 = fig.add_subplot(111)
# plt.plot(t,rho,linestyle='--',color='#808080',label='Performanzgrenzen')
# plt.plot(t,e,'g',label='Abweichung')
#
# plt.plot([0,12],[-3,-3],linestyle='--',color='#808080')
# a1.set_xlim(0,5)
# a1.set_ylim(-5,50)
# a1.set_xlabel('Zeit [s]',fontsize=18)
# a1.set_ylabel('Ausmaß der Kraft [N]',fontsize=18)
# a1.legend( fontsize=18)
# plt.xticks(fontsize=18)
# plt.yticks(fontsize=18)
# plt.grid(True)
#
# fig.savefig('first.pdf',dpi=1200)
