# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Times New Roman'

folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/noise_f0_0/'

files = [
    '2019-02-14_14-53-06_measurements.log',
    '2019-02-14_14-53-07_desired_values.log',
    '2019-02-14_14-53-08_control_output.log',
    '2019-02-14_14-53-08_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data = data.fillna(method='pad')
data.loc[:, data.columns != 'u'].plot()
plt.show()
data['u'].plot()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Times New Roman'

folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/noise_f0_1/'

files = [
    '2019-02-14_14-53-42_measurements.log',
    '2019-02-14_14-53-43_desired_values.log',
    '2019-02-14_14-53-44_control_output.log',
    '2019-02-14_14-53-43_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data = data.fillna(method='pad')
data.loc[:, data.columns != 'u'].plot()
plt.show()
data['u'].plot()
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family [u'Times New Roman'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Times New Roman'

folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/noise_f0_5/'

files = [
    '2019-02-14_14-54-06_measurements.log',
    '2019-02-14_14-54-06_desired_values.log',
    '2019-02-14_14-54-07_control_output.log',
    '2019-02-14_14-54-07_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data = data.fillna(method='pad')
data.loc[:, data.columns != 'u'].plot()
plt.show()
data['u'].plot()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Times New Roman'

folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/noise_f1_0/'

files = [
    '2019-02-14_14-54-31_measurements.log',
    '2019-02-14_14-54-32_desired_values.log',
    '2019-02-14_14-54-33_control_output.log',
    '2019-02-14_14-54-32_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data = data.fillna(method='pad')
data.loc[:, data.columns != 'u'].plot()
plt.show()
data['u'].plot()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Times New Roman'

folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/noise_f5_0/'

files = [
    '2019-02-14_15-01-56_measurements.log',
    '2019-02-14_15-01-57_desired_values.log',
    '2019-02-14_15-01-58_control_output.log',
    '2019-02-14_15-01-57_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data = data.fillna(method='pad')
data.loc[:, data.columns != 'u'].plot()
plt.show()
data['u'].plot()
plt.show()

# %%
fig= plt.figure()
a1 = fig.add_subplot(111)
plt.plot(t,rho,linestyle='--',color='#808080',label='Performanzgrenzen')
plt.plot(t,e,'g',label='Abweichung')

plt.plot([0,12],[-3,-3],linestyle='--',color='#808080')
a1.set_xlim(0,5)
a1.set_ylim(-5,50)
a1.set_xlabel('Zeit [s]',fontsize=18)
a1.set_ylabel('Ausmaß der Kraft [N]',fontsize=18)
a1.legend( fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.grid(True)

fig.savefig('first.pdf',dpi=1200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c504939eebbd> in <module>()
#       1 fig= plt.figure()
#       2 a1 = fig.add_subplot(111)
# ----> 3 plt.plot(t,rho,linestyle='--',color='#808080',label='Performanzgrenzen')
#       4 plt.plot(t,e,'g',label='Abweichung')
#       5
#
# NameError: name 't' is not defined
