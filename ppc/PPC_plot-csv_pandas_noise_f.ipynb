# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Times New Roman'

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/noise_f0_0/'

files = [
    '2019-02-14_14-53-06_measurements.log',
    '2019-02-14_14-53-07_desired_values.log',
    '2019-02-14_14-53-08_control_output.log',
    '2019-02-14_14-53-08_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data0_0 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/noise_f0_1/'

files = [
    '2019-02-14_14-53-42_measurements.log',
    '2019-02-14_14-53-43_desired_values.log',
    '2019-02-14_14-53-44_control_output.log',
    '2019-02-14_14-53-43_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')


data = df.join([df_d, de, du], how='outer')
data0_1 = data.fillna(method='pad')


#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/noise_f0_5/'

files = [
    '2019-02-14_14-54-06_measurements.log',
    '2019-02-14_14-54-06_desired_values.log',
    '2019-02-14_14-54-07_control_output.log',
    '2019-02-14_14-54-07_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data0_5 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/noise_f1_0/'

files = [
    '2019-02-14_14-54-31_measurements.log',
    '2019-02-14_14-54-32_desired_values.log',
    '2019-02-14_14-54-33_control_output.log',
    '2019-02-14_14-54-32_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data1_0 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/noise_f5_0/'

files = [
    '2019-02-14_15-01-56_measurements.log',
    '2019-02-14_15-01-57_desired_values.log',
    '2019-02-14_15-01-58_control_output.log',
    '2019-02-14_15-01-57_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data5_0 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
data5_0['f'].plot(label='sigma = 5')
data1_0['f'].plot(label='sigma = 1')
data0_5['f'].plot(label='sigma = 0.5')
data0_1['f'].plot(label='sigma = 0.1')
data0_0['f'].plot(label='sigma = 0')

data0_0['f_d'].plot(label='f_d')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_noise_f.ipynb -- f')

plt.legend()

# %%
data5_0['u'].plot(label='sigma = 5')
data1_0['u'].plot(label='sigma = 1')
data0_5['u'].plot(label='sigma = 0.5')
data0_1['u'].plot(label='sigma = 0.1')
data0_0['u'].plot(label='sigma = 0')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_noise_f.ipynb -- u')
plt.legend()

# %%
data5_0['e'].plot(label='sigma = 5')
data1_0['e'].plot(label='sigma = 1')
data0_5['e'].plot(label='sigma = 0.5')
data0_1['e'].plot(label='sigma = 0.1')
data0_0['e'].plot(label='sigma = 0')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_noise_f.ipynb -- e')
plt.legend()

# %% [raw]
# fig= plt.figure()
# a1 = fig.add_subplot(111)
# plt.plot(t,rho,linestyle='--',color='#808080',label='Performanzgrenzen')
# plt.plot(t,e,'g',label='Abweichung')
#
# plt.plot([0,12],[-3,-3],linestyle='--',color='#808080')
# a1.set_xlim(0,5)
# a1.set_ylim(-5,50)
# a1.set_xlabel('Zeit [s]',fontsize=18)
# a1.set_ylabel('Ausmaß der Kraft [N]',fontsize=18)
# a1.legend( fontsize=18)
# plt.xticks(fontsize=18)
# plt.yticks(fontsize=18)
# plt.grid(True)
#
# fig.savefig('first.pdf',dpi=1200)
