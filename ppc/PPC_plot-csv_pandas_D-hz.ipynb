# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Times New Roman'

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/D5000/'

files = [
    '2019-02-14_15-07-17_measurements.log',
    '2019-02-14_15-07-17_desired_values.log',
    '2019-02-14_15-07-18_control_output.log',
    '2019-02-14_15-07-18_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data5000_125 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-15/D5000_250hz/'

files = [
    '2019-02-15_11-36-28_measurements.log',
    '2019-02-15_11-36-28_desired_values.log',
    '2019-02-15_11-36-29_control_output.log',
    '2019-02-15_11-36-29_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data5000_250 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-15/D50000_250hz/'

files = [
    '2019-02-15_11-41-55_measurements.log',
    '2019-02-15_11-41-56_desired_values.log',
    '2019-02-15_11-41-57_control_output.log',
    '2019-02-15_11-41-57_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data50000_250 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/D50000/'

files = [
    '2019-02-14_15-08-20_measurements.log',
    '2019-02-14_15-08-21_desired_values.log',
    '2019-02-14_15-08-22_control_output.log',
    '2019-02-14_15-08-22_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data50000_125 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-15/D40000/'

files = [
    '2019-02-15_11-46-16_measurements.log',
    '2019-02-15_11-46-16_desired_values.log',
    '2019-02-15_11-46-17_control_output.log',
    '2019-02-15_11-46-17_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data40000_125 = data.fillna(method='pad')

#data40000.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-15/D40000_250hz/'

files = [
    '2019-02-15_11-58-02_measurements.log',
    '2019-02-15_11-58-03_desired_values.log',
    '2019-02-15_11-58-04_control_output.log',
    '2019-02-15_11-58-04_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data40000_250 = data.fillna(method='pad')

#data40000.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-15/D45000/'

files = [
    '2019-02-15_11-48-16_measurements.log',
    '2019-02-15_11-48-16_desired_values.log',
    '2019-02-15_11-48-17_control_output.log',
    '2019-02-15_11-48-17_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data45000_125 = data.fillna(method='pad')

#data45000.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-15/D45000_250hz/'

files = [
    '2019-02-15_11-50-04_measurements.log',
    '2019-02-15_11-50-05_desired_values.log',
    '2019-02-15_11-50-06_control_output.log',
    '2019-02-15_11-50-05_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data45000_250 = data.fillna(method='pad')

#data45000.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
col = 'f'
#data100000[col].plot(label='D = 1e5')
data5000_125[col].plot(label='D = 5000, 125hz')
data5000_250[col].plot(label='D = 5000, 250hz')

data5000_125['f_d'].plot(label='f_d')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_D-hz.ipynb -- f')

plt.legend()

# %%
col = 'u'
#data100000[col].plot(label='D = 1e5')
data5000_125[col].plot(label='D = 5000, 125hz')
data5000_250[col].plot(label='D = 5000, 250hz')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_D-hz.ipynb -- u')

plt.legend()

# %%
col = 'f'
#data100000[col].plot(label='D = 1e5')
data40000_125[col].plot(label='D = 40000, 125hz')
data40000_250[col].plot(label='D = 40000, 250hz')

data40000_125['f_d'].plot(label='f_d')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_D-hz.ipynb -- f')

plt.legend()

# %%
col = 'e'
#data100000[col].plot(label='D = 1e5')
data40000_125[col].plot(label='D = 40000, 125hz')
data40000_250[col].plot(label='D = 40000, 250hz')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_D-hz.ipynb -- e')

plt.legend()

# %%
col = 'f'
#data100000[col].plot(label='D = 1e5')
data50000_125[col].plot(label='D = 50000, 125hz')
data50000_250[col].plot(label='D = 50000, 250hz')

data50000_125['f_d'].plot(label='f_d')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_D-hz.ipynb -- f')

plt.legend()

# %%
col = 'u'
#data100000[col].plot(label='D = 1e5')
data50000_125[col].plot(label='D = 50000, 125hz')
data50000_250[col].plot(label='D = 50000, 250hz')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_D-hz.ipynb -- u')

plt.legend()

# %%
col = 'f'
#data100000[col].plot(label='D = 1e5')
data45000_125[col].plot(label='D = 45000, 125hz')
data45000_250[col].plot(label='D = 45000, 250hz')

data45000_125['f_d'].plot(label='f_d')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_D-hz.ipynb -- f')

plt.legend()

# %%
col = 'u'
#data100000[col].plot(label='D = 1e5')
data45000_125[col].plot(label='D = 45000, 125hz')
data45000_250[col].plot(label='D = 45000, 250hz')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_D-hz.ipynb -- u')

plt.legend()

# %% [raw]
# fig= plt.figure()
# a1 = fig.add_subplot(111)
# plt.plot(t,rho,linestyle='--',color='#808080',label='Performanzgrenzen')
# plt.plot(t,e,'g',label='Abweichung')
#
# plt.plot([0,12],[-3,-3],linestyle='--',color='#808080')
# a1.set_xlim(0,5)
# a1.set_ylim(-5,50)
# a1.set_xlabel('Zeit [s]',fontsize=18)
# a1.set_ylabel('Ausmaß der Kraft [N]',fontsize=18)
# a1.legend( fontsize=18)
# plt.xticks(fontsize=18)
# plt.yticks(fontsize=18)
# plt.grid(True)
#
# fig.savefig('first.pdf',dpi=1200)
