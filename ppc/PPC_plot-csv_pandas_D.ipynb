# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Times New Roman'

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/D5000/'

files = [
    '2019-02-14_15-07-17_measurements.log',
    '2019-02-14_15-07-17_desired_values.log',
    '2019-02-14_15-07-18_control_output.log',
    '2019-02-14_15-07-18_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data5000 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/D10000/'

files = [
    '2019-02-14_15-07-52_measurements.log',
    '2019-02-14_15-07-52_desired_values.log',
    '2019-02-14_15-07-54_control_output.log',
    '2019-02-14_15-07-53_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data10000 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/D25000/'

files = [
    '2019-02-14_15-16-34_measurements.log',
    '2019-02-14_15-16-35_desired_values.log',
    '2019-02-14_15-16-36_control_output.log',
    '2019-02-14_15-16-35_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data25000 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/D50000/'

files = [
    '2019-02-14_15-08-20_measurements.log',
    '2019-02-14_15-08-21_desired_values.log',
    '2019-02-14_15-08-22_control_output.log',
    '2019-02-14_15-08-22_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data50000 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
folder = '/home/lth/catkin_ws/src/pitasc/applications/ppc/logs/2019-02-14/D100000/'

files = [
    '2019-02-14_15-08-43_measurements.log',
    '2019-02-14_15-08-44_desired_values.log',
    '2019-02-14_15-08-45_control_output.log',
    '2019-02-14_15-08-44_residuals.log'
]

df = pd.read_csv(folder + files[0],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f']
                )
df = df.set_index('time')

df_d = pd.read_csv(folder + files[1],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'f_d']
                )
df_d = df_d.set_index('time')

du = pd.read_csv(folder + files[2],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'u']
                )
du = du.set_index('time')

de = pd.read_csv(folder + files[3],
                 #index_col=2,
                 usecols=[1,2],
                 header=1,
                 names=['time', 'e']
                )
de = de.set_index('time')

data = df.join([df_d, de, du], how='outer')
data100000 = data.fillna(method='pad')

#data.loc[:, data.columns != 'u'].plot()
#plt.show()
#data['u'].plot()
#plt.show()

# %%
col = 'f'
#data100000[col].plot(label='D = 1e5')
data50000[col].plot(label='D = 5e4')
data25000[col].plot(label='D = 2.5e4')
data10000[col].plot(label='D = 1e4')
data5000[col].plot(label='D = 5000')

data5000['f_d'].plot(label='f_d')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_D.ipynb -- f')

plt.legend()

# %%
col = 'u'
#data100000[col].plot(label='D = 1e5')
data50000[col].plot(label='D = 5e4')
data25000[col].plot(label='D = 2.5e4')
data10000[col].plot(label='D = 1e4')
data5000[col].plot(label='D = 5000')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_D.ipynb -- u')

plt.legend()

# %%
col = 'e'
#data100000[col].plot(label='D = 1e5')
data50000[col].plot(label='D = 5e4')
data25000[col].plot(label='D = 2.5e4')
data10000[col].plot(label='D = 1e4')
data5000[col].plot(label='D = 5000')

plt.title('jupyter_nb/ppc/PPC_plot-csv_pandas_D.ipynb -- e')

plt.legend()

# %% [raw]
# fig= plt.figure()
# a1 = fig.add_subplot(111)
# plt.plot(t,rho,linestyle='--',color='#808080',label='Performanzgrenzen')
# plt.plot(t,e,'g',label='Abweichung')
#
# plt.plot([0,12],[-3,-3],linestyle='--',color='#808080')
# a1.set_xlim(0,5)
# a1.set_ylim(-5,50)
# a1.set_xlabel('Zeit [s]',fontsize=18)
# a1.set_ylabel('Ausmaß der Kraft [N]',fontsize=18)
# a1.legend( fontsize=18)
# plt.xticks(fontsize=18)
# plt.yticks(fontsize=18)
# plt.grid(True)
#
# fig.savefig('first.pdf',dpi=1200)
